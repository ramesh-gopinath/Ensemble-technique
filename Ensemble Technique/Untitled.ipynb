# %%
mod = ["dtc","gra","xgb",]

mod = {"dtc":"DecisionTreeClassifier(criterion = 'gini', random_state=2)",
       "gra":"GradientBoostingClassifier(n_estimators = 75, learning_rate = 0.04, random_state=1)",
       "xgb":"XGBClassifier(
        learning_rate =0.1,
        n_estimators=200,
        max_depth=5,
        min_child_weight=1,
        gamma=0,
        subsample=0.8,
        colsample_bytree=0.8,
        objective='binary:logistic',
        nthread=4,
        scale_pos_weight=1,seed=27)",
       "knn":"KNeighborsClassifier(n_neighbors= 5, weights = 'distance' )",
       "log":"LogisticRegression(solver='liblinear')",
       "svc":"SVC(kernel='linear')"}

for key in mod:
    print("Key = " + key + ", Value = " + capitals[key]) 

def model(mod):
    if mod == "dtc":
        model = DecisionTreeClassifier(criterion = 'gini', random_state=2)
    else if mod == "gra":
        model = GradientBoostingClassifier(n_estimators = 75, learning_rate = 0.04, random_state=1)
    else if mod == "xgb":
        model = XGBClassifier(
        learning_rate =0.1,
        n_estimators=200,
        max_depth=5,
        min_child_weight=1,
        gamma=0,
        subsample=0.8,
        colsample_bytree=0.8,
        objective='binary:logistic',
        nthread=4,
        scale_pos_weight=1,seed=27)
    else if mod == "knn":
        model = KNeighborsClassifier(n_neighbors= 5, weights = 'distance' )
    else if mod == "log":    
        model = LogisticRegression(solver="liblinear")
    else if mod == "svc":
        model = SVC(kernel='linear')


def dtc(X_train1,y_train1,X_test1,y_test1):
        
        global model
        
        model = DecisionTreeClassifier(criterion = 'gini', random_state=2)
        model.fit(X_train1, y_train1)
        
def perform(X_train1,y_train1,X_test1,y_test1)        
        
        print("Score X_train1, y_train1",model.score(X_train1,y_train1))
        print("Score X_test1, y_test1",model.score(X_test1,y_test1))
        print("")
    
        y_pred = model.predict(X_test1)
    
        cm=metrics.confusion_matrix(y_test1, y_pred, labels=[1, 0])

        df_cm = pd.DataFrame(cm, index = [i for i in ["1","0"]],
                  columns = [i for i in ["Predict 1","Predict 0"]])
        plt.figure(figsize = (9,7))
        sns.heatmap(df_cm, annot=True)
    
        print("Accuracy ",metrics.accuracy_score(y_test1, y_pred))
        print("Precision",metrics.precision_score(y_test1, y_pred))
        print("Recall   ",metrics.recall_score(y_test1, y_pred))
        print("F1 score ",metrics.f1_score(y_test1, y_pred))
        print("ROC      ",metrics.roc_auc_score(y_test1, y_pred))

        resultsDf = pd.DataFrame({'Method':['Decision Tree'], 'Accuracy': [metrics.accuracy_score(y_test, y_pred)], 'F1_score': [metrics.f1_score(y_test,y_pred)]})
        resultsDf = resultsDf[['Method','Accuracy','F1_score']]
        resultsDf
        
        tempResultsDf = pd.DataFrame({'Method':['Random Forest'], 'Accuracy': [metrics.accuracy_score(y_test, test_pred)],'F1_score': [metrics.f1_score(y_test,y_pred)]})
        resultsDf = pd.concat([resultsDf, tempResultsDf])
        resultsDf = resultsDf[['Method','Accuracy','F1_score']]
        resultsDf
        
        return
